# %% [markdown]
# ### DATA ANALYSIS WITH PYTHON

# %% [markdown]
# #### Simple Python

# %% [markdown]
# Normal arithmatic Example

# %%
a,b,c=5,6,7

# %%
a+b
# Out:
# 11

# %%
c-b
# Out:
# 1

# %%
a*b
# Out:
# 30

# %%
a=30

# %%
a/b
# Out:
# 5.0

# %%
a/c
# Out:
# 4.285714285714286

# %%
a//c
# Out:
# 4

# %%
a%c
# Out:
# 2

# %%
a**b
# Out:
# 729000000

# %% [markdown]
# ### logical operators

# %% [markdown]
# * greator than <
# * Less than >
# * Greator than equal to <=
# * less than equal to =>
# * Not equal !=
# * equal =

# %%
a<b
# Out:
# False

# %%
b>c
# Out:
# False

# %%
a==30
# Out:
# True

# %% [markdown]
# # Python Data Types

# %% [markdown]
# * Sequence Types: list, tuple, range
# * Mapping Type: dict
# * Set Types: set, frozenset
# * Boolean Type: bool
# * Binary Types: bytes, bytearray, memoryview

# %% [markdown]
# ### INT

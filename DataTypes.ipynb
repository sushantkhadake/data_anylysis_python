# %% [markdown]
# #Builtin Datatypes in python

# %% [markdown]
# 1. Primitive Data Type
# * integer
# * float
# * Boolean
# * None
# * String
#
# 2. Non Primitive data Type
# * list
# * Tuple
# * Dictionary

# %% [markdown]
# ##variable Declaration

# %% [markdown]
# how to Declare the variable ?

# %% [markdown]
# -- Always start with Upper or Lower Char

# %% [markdown]
# -- Not with the Numerical

# %% [markdown]
# -- not with the Symbol

# %% [markdown]
# .....expect undercase(_)

# %% [markdown]
# -- all variable are case sensitive

# %% [markdown]
# ##Example's

# %%
a_var=23

# %%
type(a_var)
# Out:
# int

# %%
Abc=20.3766

# %%
type(Abc)
# Out:
# float

# %%
name = 'sush'

# %%
name
# Out:
# 'sush'

# %%
type(name)
# Out:
# str

# %%
list_hai=['abc','pqr','xyz']

# %%
list_hai
# Out:
# ['abc', 'pqr', 'xyz']

# %%
type(list_hai)
# Out:
# list

# %%
type(45*4)
# Out:
# int

# %%
type(45/3)
# Out:
# float

# %% [markdown]
# integer diviser

# %%
type(10//2)
# Out:
# int

# %% [markdown]
# ##Bool

# %% [markdown]
# either true or false (0,1)

# %%
is_true = True
is_false = False
print(is_true)
print(type(is_true))
print(is_false)
print(type(is_false))
# Out:
# True
# <class 'bool'>
# False
# <class 'bool'>

# %% [markdown]
# we can use bool as int True = 1 int and False is 0

# %%
5 + True
# Out:
# 6

# %%
5 + False
# Out:
# 5

# %%
5. + True
# Out:
# 6.0

# %% [markdown]
# Value can evaluate to False or True

# %% [markdown]
# ![Screenshot 2026-03-14 191212.png](data:image/png;base64,...)

# %% [markdown]
# only false if value is Null/empty

# %%
bool(False)
# Out:
# False

# %%
bool(())
# Out:
# False

# %%
bool([])
# Out:
# False

# %%
bool({})
# Out:
# False

# %% [markdown]
# Renge too

# %%
bool(range(0))
# Out:
# False

# %% [markdown]
# ###Values that are considerd as true

# %%
bool(True)
# Out:
# True

# %%
bool(1)
# Out:
# True

# %%
bool({1,2})
# Out:
# True

# %% [markdown]
# .......

# %% [markdown]
# ##None

# %% [markdown]
# none is type included a single value None, used to indicate the absence of a value

# %% [markdown]
# * used for later Declaration
# * avoid the case of absent value Consider as 0

# %%
nothing=None

# %%
type(nothing)
# Out:
# NoneType

# %%
my_marks=[None]

# %%
type(my_marks)
# Out:
# list

# %% [markdown]
# ##String

# %% [markdown]
# it is the Sequence of the Charaters written in the Qoutations (single/Double)

# %%
name='sush'

# %%
print(name)
# Out:
# sush

# %% [markdown]
# can't access the in third set. Eg.

# %%
srt1='don't play Dirty Games'
# Out:
#   File "/tmp/ipykernel_647/1896454953.py", line 1
#     srt1='don't play Dirty Games'
#                                 ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# so to eliminate the error we can use the '\' skip the next charater or Escape the next charater

# %%
srt1='don\'t play Dirty Games'
print(srt1)
# Out:
# don't play Dirty Games

# %% [markdown]
# ###working with multi line

# %%
str3='hii
sushi'
# Out:
#   File "/tmp/ipykernel_647/2313733687.py", line 1
#     str3='hii
#          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# use the three ''' or """ for multiple lines usaly conversastion

# %%
str3='''hii
sushi'''
print(str3)
# Out:
# hii
# sushi

# %%
multi_line_string = """This is a string
that spans multiple lines.
It's very useful for longer text.
"""
print(multi_line_string)
# Out:
# This is a string
# that spans multiple lines.
# It's very useful for longer text.

# %% [markdown]
# altho string is primery datatype but also it is a caintainor so we can perform some operations

# %% [markdown]
# ###len()

# %%
Str2='sushi'

# %%
len(Str2)
# Out:
# 5

# %%
len(multi_line_string)
# Out:
# 78

# %% [markdown]
# In Python Enter( ) is considered as one charater or one space

# %%
two_line='''sush
hii'''
two_line
# Out:
# 'sush\nhii'

# %%
len(two_line)
# Out:
# 8

# %% [markdown]
# ###list()

# %% [markdown]
# create the list of all charaters

# %%
list(str3)
# Out:
# ['h', 'i', 'i', '\n', 's', 'u', 's', 'h', 'i']

# %% [markdown]
# ##better use of string

# %% [markdown]
# ###Access the string

# %% [markdown]
# it consider char from 0-n

# %%
day='sunday'

# %%
day[3]
# Out:
# 'd'

# %%
day[5]
# Out:
# 'y'

# %% [markdown]
# Access the part of the String using index (Slice)

# %%
name='Vishwakarma'

# %%
name[0:6]
# Out:
# 'Vishwa'

# %%
name[6:11]
# Out:
# 'karma'

# %% [markdown]
# ###use of in operator

# %% [markdown]
# it used to check the whether the string contains a some text or substring

# %%
'Vishwa' in name
# Out:
# True

# %% [markdown]
# ###Concat two strings

# %% [markdown]
# two or more strings can be concatensted using the + operator

# %%
name='sushant'
greet='hello'
full_name=greet+' '+name
full_name
# Out:
# 'hello sushant'

# %% [markdown]
# ##e

# %% [markdown]
# Scientific Noation that used for denoting the power as 10

# %% [markdown]
# e- denote to denominator

# %%
one_hunderent=1e-2

# %%
one_hunderent
# Out:
# 0.01

# %% [markdown]
# e denote the 10 * (as power)

# %%
hundred=1e2

# %%
hundred
# Out:
# 100.0

# %% [markdown]
# #counter

# %%
counter=10

# %%
counter = counter + 1

# %%
counter+=4

# %%
counter
# Out:
# 15

# %% [markdown]
# 10+1+4 =15
